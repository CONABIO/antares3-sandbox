# %%
import json
from pprint import pprint
import datetime as dt

import ministac

from ministac.db import init_db, session_scope

# %%
# init_db() #init_db() just once had been executed

# %%
path_data = '/home/miuser/ministac/tests/data'

# %%
with open(path_data + '/collection_0.json') as src:
    landsat_8_collection = json.load(src)

# %%
# Register the Landsat 8 collection to the database
with session_scope() as session:
    ministac.add_collection(session, landsat_8_collection)

# %%
# Read some example items
with open(path_data + '/item_list.json') as src:
    item_list = json.load(src)

# %%
# Ingest the items to the database
with session_scope() as session:
    ministac.add_items(session, item_list, 'landsat_sr_8')

# %%
# Query the entire landsat_sr_8 collection
with session_scope() as session:
    pprint(ministac.search(session,collection='landsat_sr_8'))
# Out:
# [{'assets': {'blue': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band2.tif',
#                       'type': 'image/vnd.stac.geotiff'},
#              'green': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band3.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'metadata': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT.xml',
#                           'type': 'xml'},
#              'nir': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band5.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'pixel_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_pixel_qa.tif',
#                           'type': 'image/vnd.stac.geotiff'},
#              'radsat_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_radsat_qa.tif',
#                            'type': 'image/vnd.stac.geotiff'},
#              'red': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band4.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'swir1': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band6.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'swir2': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band7.tif',
#                        'type': 'image/vnd.stac.geotiff'}},
#   'bbox': [-102.99591, 19.14269, -100.74796, 21.30377],
#   'geometry': {'coordinates': [[[-102.99591, 21.26565],
#                                 [-102.94201, 19.14269],
#                                 [-100.74796, 19.1767],
#                                 [-100.77192, 21.30377],
#                                 [-102.99591, 21.26565]]],
#                'type': 'Polygon'},
#   'id': 'LC08_L1TP_028046_20171207_20171207_01_RT',
#   'properties': {'c:description': 'Landsat data processed to surface '
#                                   'reflectance on the espa platform',
#                  'datetime': '2017-12-07T17:12:07Z',
#                  'eo:cloud_cover': 9.77,
#                  'eo:crs': '+proj=utm +zone=14',
#                  'eo:gsd': 30,
#                  'eo:processing_level': 'L1',
#                  'eo:sensor': 'OLI_TIRS',
#                  'eo:spacecraft': 'LANDSAT_8',
#                  'landsat:wrs_path': '28',
#                  'landsat:wrs_row': '46'},
#   'type': 'Feature'},
#  {'assets': {'blue': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_sr_band2.tif',
#                       'type': 'image/vnd.stac.geotiff'},
#              'green': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_sr_band3.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'metadata': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1.xml',
#                           'type': 'xml'},
#              'nir': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_sr_band5.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'pixel_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_pixel_qa.tif',
#                           'type': 'image/vnd.stac.geotiff'},
#              'radsat_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_radsat_qa.tif',
#                            'type': 'image/vnd.stac.geotiff'},
#              'red': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_sr_band4.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'swir1': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_sr_band6.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'swir2': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_sr_band7.tif',
#                        'type': 'image/vnd.stac.geotiff'}},
#   'bbox': [-102.67498, 20.58663, -100.40693, 22.74592],
#   'geometry': {'coordinates': [[[-102.67498, 22.71003],
#                                 [-102.62155, 20.58663],
#                                 [-100.40693, 20.61885],
#                                 [-100.42774, 22.74592],
#                                 [-102.67498, 22.71003]]],
#                'type': 'Polygon'},
#   'id': 'LC08_L1TP_028045_20171121_20171206_01_T1',
#   'properties': {'c:description': 'Landsat data processed to surface '
#                                   'reflectance on the espa platform',
#                  'datetime': '2017-11-21T17:11:46Z',
#                  'eo:cloud_cover': 0.26,
#                  'eo:crs': '+proj=utm +zone=14',
#                  'eo:gsd': 30,
#                  'eo:processing_level': 'L1',
#                  'eo:sensor': 'OLI_TIRS',
#                  'eo:spacecraft': 'LANDSAT_8',
#                  'landsat:wrs_path': '28',
#                  'landsat:wrs_row': '45'},
#   'type': 'Feature'},
#  {'assets': {'blue': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band2.tif',
#                       'type': 'image/vnd.stac.geotiff'},
#              'green': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band3.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'metadata': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT.xml',
#                           'type': 'xml'},
#              'nir': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band5.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'pixel_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_pixel_qa.tif',
#                           'type': 'image/vnd.stac.geotiff'},
#              'radsat_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_radsat_qa.tif',
#                            'type': 'image/vnd.stac.geotiff'},
#              'red': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band4.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'swir1': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band6.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'swir2': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band7.tif',
#                        'type': 'image/vnd.stac.geotiff'}},
#   'bbox': [-102.66908, 20.58404, -100.40115, 22.74326],
#   'geometry': {'coordinates': [[[-102.66908, 22.70746],
#                                 [-102.61574, 20.58404],
#                                 [-100.40115, 20.61619],
#                                 [-100.42187, 22.74326],
#                                 [-102.66908, 22.70746]]],
#                'type': 'Polygon'},
#   'id': 'LC08_L1TP_028045_20171207_20171207_01_RT',
#   'properties': {'c:description': 'Landsat data processed to surface '
#                                   'reflectance on the espa platform',
#                  'datetime': '2017-12-07T17:11:43Z',
#                  'eo:cloud_cover': 3.92,
#                  'eo:crs': '+proj=utm +zone=14',
#                  'eo:gsd': 30,
#                  'eo:processing_level': 'L1',
#                  'eo:sensor': 'OLI_TIRS',
#                  'eo:spacecraft': 'LANDSAT_8',
#                  'landsat:wrs_path': '28',
#                  'landsat:wrs_row': '45'},
#   'type': 'Feature'}]

# %%
# Add temporal filter
startDate = dt.datetime(2017, 12, 1)
with session_scope() as session:
    pprint(ministac.search(session, 'landsat_sr_8', startDate=startDate))
# Out:
# [{'assets': {'blue': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band2.tif',
#                       'type': 'image/vnd.stac.geotiff'},
#              'green': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band3.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'metadata': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT.xml',
#                           'type': 'xml'},
#              'nir': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band5.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'pixel_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_pixel_qa.tif',
#                           'type': 'image/vnd.stac.geotiff'},
#              'radsat_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_radsat_qa.tif',
#                            'type': 'image/vnd.stac.geotiff'},
#              'red': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band4.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'swir1': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band6.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'swir2': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band7.tif',
#                        'type': 'image/vnd.stac.geotiff'}},
#   'bbox': [-102.99591, 19.14269, -100.74796, 21.30377],
#   'geometry': {'coordinates': [[[-102.99591, 21.26565],
#                                 [-102.94201, 19.14269],
#                                 [-100.74796, 19.1767],
#                                 [-100.77192, 21.30377],
#                                 [-102.99591, 21.26565]]],
#                'type': 'Polygon'},
#   'id': 'LC08_L1TP_028046_20171207_20171207_01_RT',
#   'properties': {'c:description': 'Landsat data processed to surface '
#                                   'reflectance on the espa platform',
#                  'datetime': '2017-12-07T17:12:07Z',
#                  'eo:cloud_cover': 9.77,
#                  'eo:crs': '+proj=utm +zone=14',
#                  'eo:gsd': 30,
#                  'eo:processing_level': 'L1',
#                  'eo:sensor': 'OLI_TIRS',
#                  'eo:spacecraft': 'LANDSAT_8',
#                  'landsat:wrs_path': '28',
#                  'landsat:wrs_row': '46'},
#   'type': 'Feature'},
#  {'assets': {'blue': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band2.tif',
#                       'type': 'image/vnd.stac.geotiff'},
#              'green': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band3.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'metadata': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT.xml',
#                           'type': 'xml'},
#              'nir': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band5.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'pixel_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_pixel_qa.tif',
#                           'type': 'image/vnd.stac.geotiff'},
#              'radsat_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_radsat_qa.tif',
#                            'type': 'image/vnd.stac.geotiff'},
#              'red': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band4.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'swir1': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band6.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'swir2': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band7.tif',
#                        'type': 'image/vnd.stac.geotiff'}},
#   'bbox': [-102.66908, 20.58404, -100.40115, 22.74326],
#   'geometry': {'coordinates': [[[-102.66908, 22.70746],
#                                 [-102.61574, 20.58404],
#                                 [-100.40115, 20.61619],
#                                 [-100.42187, 22.74326],
#                                 [-102.66908, 22.70746]]],
#                'type': 'Polygon'},
#   'id': 'LC08_L1TP_028045_20171207_20171207_01_RT',
#   'properties': {'c:description': 'Landsat data processed to surface '
#                                   'reflectance on the espa platform',
#                  'datetime': '2017-12-07T17:11:43Z',
#                  'eo:cloud_cover': 3.92,
#                  'eo:crs': '+proj=utm +zone=14',
#                  'eo:gsd': 30,
#                  'eo:processing_level': 'L1',
#                  'eo:sensor': 'OLI_TIRS',
#                  'eo:spacecraft': 'LANDSAT_8',
#                  'landsat:wrs_path': '28',
#                  'landsat:wrs_row': '45'},
#   'type': 'Feature'}]

# %%
# Spatial filter
geom = {'coordinates': [[[-101.7, 19.59],
                         [-101.66, 19.54],
                         [-101.61, 19.56],
                         [-101.64, 19.58],
                         [-101.57, 19.63],
                         [-101.54, 19.66],
                         [-101.6, 19.68],
                         [-101.64, 19.64],
                         [-101.7, 19.59]]],
        'type': 'Polygon'}

with session_scope() as session:
    pprint(ministac.search(session, 'landsat_sr_8', geom=geom))
# Out:
# [{'assets': {'blue': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band2.tif',
#                       'type': 'image/vnd.stac.geotiff'},
#              'green': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band3.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'metadata': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT.xml',
#                           'type': 'xml'},
#              'nir': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band5.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'pixel_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_pixel_qa.tif',
#                           'type': 'image/vnd.stac.geotiff'},
#              'radsat_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_radsat_qa.tif',
#                            'type': 'image/vnd.stac.geotiff'},
#              'red': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band4.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'swir1': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band6.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'swir2': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band7.tif',
#                        'type': 'image/vnd.stac.geotiff'}},
#   'bbox': [-102.99591, 19.14269, -100.74796, 21.30377],
#   'geometry': {'coordinates': [[[-102.99591, 21.26565],
#                                 [-102.94201, 19.14269],
#                                 [-100.74796, 19.1767],
#                                 [-100.77192, 21.30377],
#                                 [-102.99591, 21.26565]]],
#                'type': 'Polygon'},
#   'id': 'LC08_L1TP_028046_20171207_20171207_01_RT',
#   'properties': {'c:description': 'Landsat data processed to surface '
#                                   'reflectance on the espa platform',
#                  'datetime': '2017-12-07T17:12:07Z',
#                  'eo:cloud_cover': 9.77,
#                  'eo:crs': '+proj=utm +zone=14',
#                  'eo:gsd': 30,
#                  'eo:processing_level': 'L1',
#                  'eo:sensor': 'OLI_TIRS',
#                  'eo:spacecraft': 'LANDSAT_8',
#                  'landsat:wrs_path': '28',
#                  'landsat:wrs_row': '46'},
#   'type': 'Feature'}]

# %%
# Filter with cloud cover threshold
with session_scope() as session:
    pprint(ministac.search(session, 'landsat_sr_8', maxCloudCover=20))
# Out:
# [{'assets': {'blue': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band2.tif',
#                       'type': 'image/vnd.stac.geotiff'},
#              'green': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band3.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'metadata': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT.xml',
#                           'type': 'xml'},
#              'nir': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band5.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'pixel_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_pixel_qa.tif',
#                           'type': 'image/vnd.stac.geotiff'},
#              'radsat_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_radsat_qa.tif',
#                            'type': 'image/vnd.stac.geotiff'},
#              'red': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band4.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'swir1': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band6.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'swir2': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280462017120701RT-SC20171213123909/LC08_L1TP_028046_20171207_20171207_01_RT_sr_band7.tif',
#                        'type': 'image/vnd.stac.geotiff'}},
#   'bbox': [-102.99591, 19.14269, -100.74796, 21.30377],
#   'geometry': {'coordinates': [[[-102.99591, 21.26565],
#                                 [-102.94201, 19.14269],
#                                 [-100.74796, 19.1767],
#                                 [-100.77192, 21.30377],
#                                 [-102.99591, 21.26565]]],
#                'type': 'Polygon'},
#   'id': 'LC08_L1TP_028046_20171207_20171207_01_RT',
#   'properties': {'c:description': 'Landsat data processed to surface '
#                                   'reflectance on the espa platform',
#                  'datetime': '2017-12-07T17:12:07Z',
#                  'eo:cloud_cover': 9.77,
#                  'eo:crs': '+proj=utm +zone=14',
#                  'eo:gsd': 30,
#                  'eo:processing_level': 'L1',
#                  'eo:sensor': 'OLI_TIRS',
#                  'eo:spacecraft': 'LANDSAT_8',
#                  'landsat:wrs_path': '28',
#                  'landsat:wrs_row': '46'},
#   'type': 'Feature'},
#  {'assets': {'blue': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_sr_band2.tif',
#                       'type': 'image/vnd.stac.geotiff'},
#              'green': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_sr_band3.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'metadata': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1.xml',
#                           'type': 'xml'},
#              'nir': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_sr_band5.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'pixel_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_pixel_qa.tif',
#                           'type': 'image/vnd.stac.geotiff'},
#              'radsat_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_radsat_qa.tif',
#                            'type': 'image/vnd.stac.geotiff'},
#              'red': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_sr_band4.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'swir1': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_sr_band6.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'swir2': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017112101T1-SC20171213123932/LC08_L1TP_028045_20171121_20171206_01_T1_sr_band7.tif',
#                        'type': 'image/vnd.stac.geotiff'}},
#   'bbox': [-102.67498, 20.58663, -100.40693, 22.74592],
#   'geometry': {'coordinates': [[[-102.67498, 22.71003],
#                                 [-102.62155, 20.58663],
#                                 [-100.40693, 20.61885],
#                                 [-100.42774, 22.74592],
#                                 [-102.67498, 22.71003]]],
#                'type': 'Polygon'},
#   'id': 'LC08_L1TP_028045_20171121_20171206_01_T1',
#   'properties': {'c:description': 'Landsat data processed to surface '
#                                   'reflectance on the espa platform',
#                  'datetime': '2017-11-21T17:11:46Z',
#                  'eo:cloud_cover': 0.26,
#                  'eo:crs': '+proj=utm +zone=14',
#                  'eo:gsd': 30,
#                  'eo:processing_level': 'L1',
#                  'eo:sensor': 'OLI_TIRS',
#                  'eo:spacecraft': 'LANDSAT_8',
#                  'landsat:wrs_path': '28',
#                  'landsat:wrs_row': '45'},
#   'type': 'Feature'},
#  {'assets': {'blue': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band2.tif',
#                       'type': 'image/vnd.stac.geotiff'},
#              'green': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band3.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'metadata': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT.xml',
#                           'type': 'xml'},
#              'nir': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band5.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'pixel_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_pixel_qa.tif',
#                           'type': 'image/vnd.stac.geotiff'},
#              'radsat_qa': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_radsat_qa.tif',
#                            'type': 'image/vnd.stac.geotiff'},
#              'red': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band4.tif',
#                      'type': 'image/vnd.stac.geotiff'},
#              'swir1': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band6.tif',
#                        'type': 'image/vnd.stac.geotiff'},
#              'swir2': {'href': '/media/loic/data/datacube_tests/landsat_espa/LC080280452017120701RT-SC20171213124014/LC08_L1TP_028045_20171207_20171207_01_RT_sr_band7.tif',
#                        'type': 'image/vnd.stac.geotiff'}},
#   'bbox': [-102.66908, 20.58404, -100.40115, 22.74326],
#   'geometry': {'coordinates': [[[-102.66908, 22.70746],
#                                 [-102.61574, 20.58404],
#                                 [-100.40115, 20.61619],
#                                 [-100.42187, 22.74326],
#                                 [-102.66908, 22.70746]]],
#                'type': 'Polygon'},
#   'id': 'LC08_L1TP_028045_20171207_20171207_01_RT',
#   'properties': {'c:description': 'Landsat data processed to surface '
#                                   'reflectance on the espa platform',
#                  'datetime': '2017-12-07T17:11:43Z',
#                  'eo:cloud_cover': 3.92,
#                  'eo:crs': '+proj=utm +zone=14',
#                  'eo:gsd': 30,
#                  'eo:processing_level': 'L1',
#                  'eo:sensor': 'OLI_TIRS',
#                  'eo:spacecraft': 'LANDSAT_8',
#                  'landsat:wrs_path': '28',
#                  'landsat:wrs_row': '45'},
#   'type': 'Feature'}]
