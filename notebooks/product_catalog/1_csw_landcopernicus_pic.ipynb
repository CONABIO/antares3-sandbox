# %%
import requests

# %% [markdown]
# # Para land copernicus

# %% [markdown]
# Algunas líneas con curl que resultaron exitosas

# %% [markdown]
# ```
# curl -X POST "https://sdi.eea.europa.eu/catalogue/copernicus/eng/csw?request=GetRecords&service=CSW&version=2.0.2&resultType=results&typeNames=csw:Record&ElementSetName=full&outputSchema=http://www.isotc211.org/2005/gmd"
# ```
#
# ```
# curl -X GET "https://sdi.eea.europa.eu/catalogue/copernicus/eng/csw?request=GetRecords&service=CSW&version=2.0.2&resultType=results&typeNames=csw:Record&ElementSetName=full&outputSchema=http://www.isotc211.org/2005/gmd"
# ```
#
# ```
# #con typename gmd:MD_Metadata
#
# curl -X GET "https://sdi.eea.europa.eu/catalogue/copernicus/eng/csw?request=GetRecords&service=CSW&version=2.0.2&resultType=results&typeNames=gmd:MD_Metadata&ElementSetName=full&outputSchema=http://www.isotc211.org/2005/gmd"
# ```
#
# ```
# #con otro schema
# curl -X GET "https://sdi.eea.europa.eu/catalogue/copernicus/eng/csw?request=GetRecords&version=2.0.2&SERVICE=CSW&outputFormat=application/xml&outputSchema=http://www.opengis.net/cat/csw/2.0.2&namespace=csw:http://www.opengis.org/cat/csw&typeNameS=csw:Record&ElementSetName=brief"
#
# <?xml version="1.0" encoding="UTF-8"?>
# <csw:GetRecordsResponse xmlns:csw="http://www.opengis.net/cat/csw/2.0.2" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.opengis.net/cat/csw/2.0.2 http://schemas.opengis.net/csw/2.0.2/CSW-discovery.xsd">
#   <csw:SearchStatus timestamp="2019-11-22T19:56:56" />
#   <csw:SearchResults numberOfRecordsMatched="74" numberOfRecordsReturned="10" elementSet="brief" nextRecord="11" />
# </csw:GetRecordsResponse>
# ```

# %% [markdown]
# ## Con requests de python

# %%
r=requests.get('https://sdi.eea.europa.eu/catalogue/copernicus/eng/csw?request=GetRecords&service=CSW&version=2.0.2&resultType=results&typeNames=gmd:MD_Metadata&ElementSetName=full&outputSchema=http://www.isotc211.org/2005/gmd')

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\r\n<csw:GetRecordsResponse xmlns:csw="http://www.opengis.net/cat/csw/2.0.2" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.opengis.net/cat/csw/2.0.2 http://schemas.opengis.net/csw/2.0.2/CSW-discovery.xsd">\r\n  <csw:SearchStatus timestamp="2019-11-22T20:10:41" />\r\n  <csw:SearchResults numberOfRecordsMatched="74" numberOfRecordsReturned="10" elementSet="full" nextRecord="11">\r\n    <gmd:MD_Metadata xmlns:gmd="http://www.isotc211.org/2005/gmd" xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:gco="http://www.isotc211.org/2005/gco" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:geonet="http://www.fao.org/geonetwork" xsi:schemaLocation="http://www.isotc211.org/2005/gmd http://schemas.opengis.net/csw/2.0.2/profiles/apiso/1.0.0/apiso.xsd">\r\n      <gmd:fileIdentifier>\r\n        <gco:CharacterString>9a7fada2-df50-448b-8ccf-c2bbcd9b6ad8</gco:CharacterString>\r\n      </gmd:fileIdentifier>\r\n      <gmd:langua
# ...

# %%
r=requests.get('https://sdi.eea.europa.eu/catalogue/copernicus/eng/csw?request=GetRecords&version=2.0.2&SERVICE=CSW&outputFormat=application/xml&outputSchema=http://www.opengis.net/cat/csw/2.0.2&namespace=csw:http://www.opengis.org/cat/csw&typeNameS=csw:Record&ElementSetName=brief')

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\r\n<csw:GetRecordsResponse xmlns:csw="http://www.opengis.net/cat/csw/2.0.2" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.opengis.net/cat/csw/2.0.2 http://schemas.opengis.net/csw/2.0.2/CSW-discovery.xsd">\r\n  <csw:SearchStatus timestamp="2019-11-22T20:10:49" />\r\n  <csw:SearchResults numberOfRecordsMatched="1338" numberOfRecordsReturned="10" elementSet="brief" nextRecord="11" />\r\n</csw:GetRecordsResponse>\r\n\r\n'

# %% [markdown]
# # Para pic

# %% [markdown]
# Algunas líneas con curl que funcionaron

# %% [markdown]
# ```
# curl -X GET "http://pic.conabio.gob.mx:8080/geonetwork/srv/spa/csw?request=GetRecords&service=CSW&version=2.0.2&resultType=results&typeNames=csw:Record&ElementSetName=full&outputSchema=http://www.isotc211.org/2005/gmd"
#
# curl -u <user> -X GET "https://pic.conabio.gob.mx/geonetwork/srv/api/0.1/users" -H  "accept: application/json" -H  "X-XSRF-TOKEN: null"
#
# #también funciona sin el token
# curl -u <user> -X GET "https://pic.conabio.gob.mx/geonetwork/srv/api/0.1/users" -H  "accept: application/json"
# ```
#
#
# ```
# #el siguiente también funciona sin admin
#
# curl -u <user> -X GET "http://pic.conabio.gob.mx:8080/geonetwork/srv/spa/csw?request=GetRecords&version=2.0.2&SERVICE=CSW&outputFormat=application/xml&outputSchema=http://www.opengis.net/cat/csw/2.0.2&namespace=csw:http://www.opengis.org/cat/csw&typeNameS=csw:Record&ElementSetName=brief"
# Enter host password for user 'admin':
#
# <?xml version="1.0" encoding="UTF-8"?>
# <csw:GetRecordsResponse xmlns:csw="http://www.opengis.net/cat/csw/2.0.2" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.opengis.net/cat/csw/2.0.2 http://schemas.opengis.net/csw/2.0.2/CSW-discovery.xsd">
#   <csw:SearchStatus timestamp="2019-11-22T13:44:32" />
#   <csw:SearchResults numberOfRecordsMatched="17" numberOfRecordsReturned="10" elementSet="brief" nextRecord="11" />
# </csw:GetRecordsResponse>
#
# ```
#
# ```
# #con json
#
# curl -X GET "http://pic.conabio.gob.mx:8080/geonetwork/srv/spa/q?title=Africa&_content_type=json&fast=index&resultType=details&sortBy=relevance"
# ```

# %% [markdown]
# ## Con requests de python

# %%
r=requests.get('http://pic.conabio.gob.mx/geonetwork/srv/spa/catalog.search#/metadata/da165110-88fd-11da-a88f-000d939bc5d8')

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# **esto fue éxito**

# %%
r.text
# Out:
# '<!DOCTYPE html\n  SYSTEM "html">\n<html ng-app="gn_search_default" lang="es" id="ng-app">\n   <head>\n      <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n      <title>DGPI - CONABIO</title>\n      <meta charset="utf-8">\n      <meta name="viewport" content="initial-scale=1.0, user-scalable=no">\n      <meta name="apple-mobile-web-app-capable" content="yes">\n      <meta name="description" content="">\n      <meta name="keywords" content="">\n      <link rel="icon" sizes="16x16 32x32 48x48" type="image/png" href="../../images/logos/favicon.png">\n      <link href="rss.search?sortBy=changeDate" rel="alternate" type="application/rss+xml" title="DGPI - CONABIO">\n      <link href="portal.opensearch" rel="search" type="application/opensearchdescription+xml" title="DGPI - CONABIO">\n      <link href="/geonetwork/static/gn_search_default.css" rel="stylesheet" media="screen">\n      <link href="/geonetwork/static/bootstrap-table.min.css" rel="stylesheet" media="screen
# ...

# %%
r.request
# Out:
# <PreparedRequest [GET]>

# %%
r.raw

# %%
r.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
r.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-30-52b7ec8d97cc> in <module>
# ----> 1 r.json()
#
# /usr/lib/python3/dist-packages/requests/models.py in json(self, **kwargs)
#     806                     # used.
#     807                     pass
# --> 808         return complexjson.loads(self.text, **kwargs)
#     809
#     810     @property
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /usr/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# ...

# %%
r = requests.get('https://pic.conabio.gob.mx/geonetwork/srv/api/0.1/users', auth=('admin', 'admin'))

# %%
r.status_code
# Out:
# 400

# %% [markdown]
# **esto fue error**

# %%
r.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><apiError><code>runtime_exception</code><description>Could not find acceptable representation</description><message>HttpMediaTypeNotAcceptableException</message></apiError>'

# %%
r = requests.get('http://pic.conabio.gob.mx:8080/geonetwork/srv/spa/csw?request=GetRecords&service=CSW&version=2.0.2&resultType=results&typeNames=csw:Record&ElementSetName=full&outputSchema=http://www.isotc211.org/2005/gmd')

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\r\n<csw:GetRecordsResponse xmlns:csw="http://www.opengis.net/cat/csw/2.0.2" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.opengis.net/cat/csw/2.0.2 http://schemas.opengis.net/csw/2.0.2/CSW-discovery.xsd">\r\n  <csw:SearchStatus timestamp="2019-11-22T14:16:04" />\r\n  <csw:SearchResults numberOfRecordsMatched="5" numberOfRecordsReturned="5" elementSet="full" nextRecord="0">\r\n    <!--OutputSchema \'gmd\' not supported for metadata with \'144\' (dublin-core).\nCorresponding XSL transformation \'gmd-full.xsl\' does not exist for this schema.\nThe record will not be returned in response.-->\r\n    <gmd:MD_Metadata xmlns:gmd="http://www.isotc211.org/2005/gmd" xmlns:gml="http://www.opengis.net/gml" xmlns:gmx="http://www.isotc211.org/2005/gmx" xmlns:gts="http://www.isotc211.org/2005/gts" xmlns:gco="http://www.isotc211.org/2005/gco" xmlns:gsr="http://www.isotc211.org/2005/gsr" xmlns:xlink="http://www.w3.org/1999/
# ...

# %%
r = requests.get('http://pic.conabio.gob.mx:8080/geonetwork/srv/spa/csw?request=GetRecords&version=2.0.2&SERVICE=CSW&outputFormat=application/xml&outputSchema=http://www.opengis.net/cat/csw/2.0.2&namespace=csw:http://www.opengis.org/cat/csw&typeNameS=csw:Record&ElementSetName=brief')

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\r\n<csw:GetRecordsResponse xmlns:csw="http://www.opengis.net/cat/csw/2.0.2" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.opengis.net/cat/csw/2.0.2 http://schemas.opengis.net/csw/2.0.2/CSW-discovery.xsd">\r\n  <csw:SearchStatus timestamp="2019-11-22T14:16:04" />\r\n  <csw:SearchResults numberOfRecordsMatched="5" numberOfRecordsReturned="5" elementSet="brief" nextRecord="0" />\r\n</csw:GetRecordsResponse>\r\n\r\n'

# %% [markdown]
# Using https://geonetwork-opensource.org/manuals/trunk/eng/users/api/q-search.html

# %%
r = requests.get('http://pic.conabio.gob.mx:8080/geonetwork/srv/spa/q?title=Africa&_content_type=json&fast=index&resultType=details&sortBy=relevance')

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '{\n  "@from": "1",\n  "@to": "1",\n  "@selected": "0",\n  "summary":   {\n    "@count": "1",\n    "@type": "local",\n    "dimension":     [\n            {\n        "@name": "type",\n        "@label": "types",\n        "category":         {\n          "@value": "dataset",\n          "@label": "Conjunto de datos",\n          "@count": "1"\n        }\n      },\n            {\n        "@name": "mdActions",\n        "@label": "mdActions",\n        "category":         [\n                    {\n            "@value": "mdActions-view",\n            "@label": "mdActions-view",\n            "@count": "1"\n          },\n                    {\n            "@value": "mdActions-download",\n            "@label": "mdActions-download",\n            "@count": "1"\n          }\n        ]\n      },\n            {\n        "@name": "topicCat",\n        "@label": "topicCats"\n      },\n            {\n        "@name": "inspireThemeURI",\n        "@label": "inspireThemesURI"\n      },\n            {\n      
# ...

# %%
r.json()
# Out:
# {'@from': '1',
#  '@to': '1',
#  '@selected': '0',
#  'summary': {'@count': '1',
#   '@type': 'local',
#   'dimension': [{'@name': 'type',
#     '@label': 'types',
#     'category': {'@value': 'dataset',
#      '@label': 'Conjunto de datos',
#      '@count': '1'}},
#    {'@name': 'mdActions',
#     '@label': 'mdActions',
#     'category': [{'@value': 'mdActions-view',
#       '@label': 'mdActions-view',
#       '@count': '1'},
#      {'@value': 'mdActions-download',
#       '@label': 'mdActions-download',
#       '@count': '1'}]},
#    {'@name': 'topicCat', '@label': 'topicCats'},
#    {'@name': 'inspireThemeURI', '@label': 'inspireThemesURI'},
#    {'@name': 'keyword', '@label': 'keywords'},
#    {'@name': 'orgName', '@label': 'orgNames'},
#    {'@name': 'sourceCatalog',
#     '@label': 'sourceCatalog',
#     'category': {'@value': '2015754a-8f5c-4979-8bfc-24f13ad6d226',
#      '@label': 'DGPI',
#      '@count': '1'}},
#    {'@name': 'createDateYear',
# ...

# %%
d = r.json()

# %%
d.keys()
# Out:
# dict_keys(['@from', '@to', '@selected', 'summary', 'metadata'])

# %%
d.items()
# Out:
# dict_items([('@from', '1'), ('@to', '1'), ('@selected', '0'), ('summary', {'@count': '1', '@type': 'local', 'dimension': [{'@name': 'type', '@label': 'types', 'category': {'@value': 'dataset', '@label': 'Conjunto de datos', '@count': '1'}}, {'@name': 'mdActions', '@label': 'mdActions', 'category': [{'@value': 'mdActions-view', '@label': 'mdActions-view', '@count': '1'}, {'@value': 'mdActions-download', '@label': 'mdActions-download', '@count': '1'}]}, {'@name': 'topicCat', '@label': 'topicCats'}, {'@name': 'inspireThemeURI', '@label': 'inspireThemesURI'}, {'@name': 'keyword', '@label': 'keywords'}, {'@name': 'orgName', '@label': 'orgNames'}, {'@name': 'sourceCatalog', '@label': 'sourceCatalog', 'category': {'@value': '2015754a-8f5c-4979-8bfc-24f13ad6d226', '@label': 'DGPI', '@count': '1'}}, {'@name': 'createDateYear', '@label': 'createDateYears', 'category': {'@value': '2000', '@label': '2000', '@count': '1'}}, {'@name': 'format', '@label': 'formats', 'category': {'@value': 'ShapeFil
# ...

# %%
d['summary']
# Out:
# {'@count': '1',
#  '@type': 'local',
#  'dimension': [{'@name': 'type',
#    '@label': 'types',
#    'category': {'@value': 'dataset',
#     '@label': 'Conjunto de datos',
#     '@count': '1'}},
#   {'@name': 'mdActions',
#    '@label': 'mdActions',
#    'category': [{'@value': 'mdActions-view',
#      '@label': 'mdActions-view',
#      '@count': '1'},
#     {'@value': 'mdActions-download',
#      '@label': 'mdActions-download',
#      '@count': '1'}]},
#   {'@name': 'topicCat', '@label': 'topicCats'},
#   {'@name': 'inspireThemeURI', '@label': 'inspireThemesURI'},
#   {'@name': 'keyword', '@label': 'keywords'},
#   {'@name': 'orgName', '@label': 'orgNames'},
#   {'@name': 'sourceCatalog',
#    '@label': 'sourceCatalog',
#    'category': {'@value': '2015754a-8f5c-4979-8bfc-24f13ad6d226',
#     '@label': 'DGPI',
#     '@count': '1'}},
#   {'@name': 'createDateYear',
#    '@label': 'createDateYears',
#    'category': {'@value': '2000', '@label': '2000', '@count': '1'}},
# ...

# %%
d_meta = d['metadata']

# %%
d_meta
# Out:
# {'lineage': 'The linework of the map is obtained by delineating drainage basin boundaries from an hydrologically corrected digital elevation model with a resolution of 1 * 1 km.',
#  'responsibleParty': 'Point of contact|metadata|FAO - NRCW||jippe.hoogeveen@fao.org|Jippe Hoogeveen|Technical Officer|Viale delle Terme di Caracalla, Rome, 00153, Italy|||1',
#  'type': 'dataset',
#  'isHarvested': 'n',
#  'displayOrder': '0',
#  'docLocale': 'eng',
#  'popularity': '3',
#  'keyword': ['watersheds',
#   'river basins',
#   'water resources',
#   'hydrology',
#   'AQUASTAT',
#   'AWRD',
#   'Africa',
#   'Inland waters'],
#  'publishedForGroup': ['0', '1', '2'],
#  'image': ['thumbnail|http://localhost:8080/geonetwork/srv/api/records/da165110-88fd-11da-a88f-000d939bc5d8/attachments/thumbnail_s.gif|Hydrological Basins in Africa (small preview)',
# ...

# %%
d_meta.keys()
# Out:
# dict_keys(['lineage', 'responsibleParty', 'type', 'isHarvested', 'displayOrder', 'docLocale', 'popularity', 'keyword', 'publishedForGroup', 'image', 'tempExtentBegin', 'mdLanguage', 'crsDetails', 'maintenanceAndUpdateFrequency_text', 'format', 'spatialRepresentationType_text', 'denominator', 'root', 'isTemplate', 'valid', 'feedbackCount', 'tempExtentEnd', 'rating', 'source', 'category', 'status', 'updateFrequency', 'geoBox', 'owner', 'defaultAbstract', 'link', 'defaultTitle', 'datasetLang', 'userinfo', 'topicCat', 'status_text', 'creationDate', 'standardName', 'crs', 'logo', 'abstract', 'keywordGroup', '_locale', 'geonet:info'])

# %%
d_meta['geoBox']
# Out:
# '-17.3|-34.6|51.1|38.2'

# %%
d_meta['geonet:info']
# Out:
# {'@xmlns:geonet': 'http://www.fao.org/geonetwork',
#  'id': '141',
#  'uuid': 'da165110-88fd-11da-a88f-000d939bc5d8',
#  'schema': 'iso19139',
#  'createDate': '2007-07-19T14:45:07',
#  'changeDate': '2019-10-02T13:39:28',
#  'source': '2015754a-8f5c-4979-8bfc-24f13ad6d226',
#  'isPublishedToAll': 'true',
#  'view': 'true',
#  'notify': 'false',
#  'download': 'true',
#  'dynamic': 'true',
#  'featured': 'true',
#  'selected': 'false'}

# %%
d_meta['geonet:info']['schema']
# Out:
# 'iso19139'
