# %%
# %matplotlib inline
import matplotlib
from madmex.wrappers import gwf_query
from datetime import datetime
import datetime as dt
import xarray as xr
import numpy as np
from madmex.util.xarray import to_float, to_int
from datacube.api import GridWorkflow
# Out:
# /usr/local/lib/python3.6/dist-packages/dask/array/blockwise.py:204: UserWarning: The da.atop function has moved to da.blockwise
# 2019-11-07 16:57:31,654 - madmex.wrappers - loggerwriter write: /usr/local/lib/python3.6/dist-packages/dask/array/blockwise.py:204: UserWarning: The da.atop function has moved to da.blockwise
#   warnings.warn("The da.atop function has moved to da.blockwise")
# 2019-11-07 16:57:31,656 - madmex.wrappers - loggerwriter write:   warnings.warn("The da.atop function has moved to da.blockwise")
# /usr/local/lib/python3.6/dist-packages/dask/array/blockwise.py:204: UserWarning: The da.atop function has moved to da.blockwise
# 2019-11-07 16:57:43,094 - madmex.wrappers - loggerwriter write: /usr/local/lib/python3.6/dist-packages/dask/array/blockwise.py:204: UserWarning: The da.atop function has moved to da.blockwise
#   warnings.warn("The da.atop function has moved to da.blockwise")
# 2019-11-07 16:57:43,096 - madmex.wrappers - loggerwriter write:   warnings.warn("The da.atop function has moved to da.blockwise")
# /usr/local/lib/python3.6/dist-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
# 2019-11-07 16:58:26,522 - madmex.wrappers - loggerwriter write: /usr/local/lib/python3.6/dist-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*args2)
# 2019-11-07 16:58:26,524 - madmex.wrappers - loggerwriter write:   return func(*args2)
# /usr/local/lib/python3.6/dist-packages/dask/compatibility.py:93: RuntimeWarning: All-NaN slice encountered
# 2019-11-07 16:58:26,911 - madmex.wrappers - loggerwriter write: /usr/local/lib/python3.6/dist-packages/dask/compatibility.py:93: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# 2019-11-07 16:58:26,923 - madmex.wrappers - loggerwriter write:   return func(*args, **kwargs)
# /usr/local/lib/python3.6/dist-packages/toolz/functoolz.py:468: RuntimeWarning: All-NaN slice encountered
# 2019-11-07 16:58:27,182 - madmex.wrappers - loggerwriter write: /usr/local/lib/python3.6/dist-packages/toolz/functoolz.py:468: RuntimeWarning: All-NaN slice encountered
#   ret = f(ret)
# 2019-11-07 16:58:27,231 - madmex.wrappers - loggerwriter write:   ret = f(ret)
# /usr/local/lib/python3.6/dist-packages/dask/array/blockwise.py:204: UserWarning: The da.atop function has moved to da.blockwise
# 2019-11-07 16:59:37,984 - madmex.wrappers - loggerwriter write: /usr/local/lib/python3.6/dist-packages/dask/array/blockwise.py:204: UserWarning: The da.atop function has moved to da.blockwise
#   warnings.warn("The da.atop function has moved to da.blockwise")
# 2019-11-07 16:59:37,995 - madmex.wrappers - loggerwriter write:   warnings.warn("The da.atop function has moved to da.blockwise")
# /usr/local/lib/python3.6/dist-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
# 2019-11-07 16:59:57,423 - madmex.wrappers - loggerwriter write: /usr/local/lib/python3.6/dist-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*args2)
# 2019-11-07 16:59:57,425 - madmex.wrappers - loggerwriter write:   return func(*args2)
# /usr/local/lib/python3.6/dist-packages/dask/compatibility.py:93: RuntimeWarning: All-NaN slice encountered
# 2019-11-07 16:59:58,002 - madmex.wrappers - loggerwriter write: /usr/local/lib/python3.6/dist-packages/dask/compatibility.py:93: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# 2019-11-07 16:59:58,008 - madmex.wrappers - loggerwriter write:   return func(*args, **kwargs)
# /usr/local/lib/python3.6/dist-packages/toolz/functoolz.py:468: RuntimeWarning: All-NaN slice encountered
# 2019-11-07 16:59:58,233 - madmex.wrappers - loggerwriter write: /usr/local/lib/python3.6/dist-packages/toolz/functoolz.py:468: RuntimeWarning: All-NaN slice encountered
#   ret = f(ret)
# 2019-11-07 16:59:58,238 - madmex.wrappers - loggerwriter write:   ret = f(ret)

# %%
options = {}
#x = (-97.833251953125, -96.6522216796875)
x = (-97.833251953125,-97.4395751953125)
#y = (19.756364230752375, 20.648205934292623)
y = (20.5, 20.6)
options['lat'] = y
options['long'] = x
options['region'] = None
options['begin'] = "2019-01-1"
options['end'] = "2020-01-1"

# %%
name_of_product = 's2_l2a_10m_scl_mexico'

# %%
begin_time = datetime.strptime(options['begin'], '%Y-%m-%d')

# %%
gwf_kwargs = { k: options[k] for k in ['lat', 'long', 'region', 'begin', 'end']}
gwf_kwargs.update(product=name_of_product)
iterable = gwf_query(**gwf_kwargs)

# %%
len(iterable)
# Out:
# 1

# %%
tile = list(iterable)[0]

# %%
sr_0 = xr.merge([GridWorkflow.load(tile[1], dask_chunks={'time': -1},#{'x': 100, 'y': 100},
                                   measurements=['red','nir','pixel_qa'])])

# %%
sr_0
# Out:
# <xarray.Dataset>
# Dimensions:   (time: 10, x: 5002, y: 5002)
# Coordinates:
#   * time      (time) datetime64[ns] 2019-01-07T17:18:02 ... 2019-04-04T17:08:13.240000
#   * y         (y) float64 9.761e+05 9.761e+05 9.761e+05 ... 9.261e+05 9.261e+05
#   * x         (x) float64 2.928e+06 2.928e+06 2.928e+06 ... 2.978e+06 2.978e+06
# Data variables:
#     red       (time, y, x) uint16 dask.array<shape=(10, 5002, 5002), chunksize=(10, 5002, 5002)>
#     nir       (time, y, x) uint16 dask.array<shape=(10, 5002, 5002), chunksize=(10, 5002, 5002)>
#     pixel_qa  (time, y, x) uint16 dask.array<shape=(10, 5002, 5002), chunksize=(10, 5002, 5002)>

# %%
sr_0['ndvi'] = ((sr_0.nir-sr_0.red)/(sr_0.nir+sr_0.red))

# %%
matplotlib.rcParams['figure.figsize'] = [12, 8]

# %%
#sr_0.ndvi[0,:,:].plot()

# %%
begin_time - datetime.utcfromtimestamp(sr_0['time'][0].values.astype(datetime)*1e-9)
# Out:
# datetime.timedelta(-7, 24118)

# %%
# nearest in recent version has tolerance argument to limit nearest values. That could mean Na's but avoid values too far
ts_1 = sr_0.ndvi.resample(time='10D', 
                   loffset=begin_time - 
                   datetime.utcfromtimestamp(sr_0['time'][0].values.astype(datetime)*1e-9)).nearest().interpolate_na('time')

# %%
ts_1['time']
# Out:
# <xarray.DataArray 'time' (time: 9)>
# array(['2019-01-01T00:00:00.000000000', '2019-01-11T00:00:00.000000000',
#        '2019-01-21T00:00:00.000000000', '2019-01-31T00:00:00.000000000',
#        '2019-02-10T00:00:00.000000000', '2019-02-20T00:00:00.000000000',
#        '2019-03-02T00:00:00.000000000', '2019-03-12T00:00:00.000000000',
#        '2019-03-22T00:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2019-01-01 2019-01-11 ... 2019-03-22
# Attributes:
#     units:    seconds since 1970-01-01 00:00:00

# %%
ts_1
# Out:
# <xarray.DataArray 'ndvi' (time: 9, y: 5002, x: 5002)>
# dask.array<shape=(9, 5002, 5002), dtype=float64, chunksize=(9, 5002, 5002)>
# Coordinates:
#   * time     (time) datetime64[ns] 2019-01-01 2019-01-11 ... 2019-03-22
#   * y        (y) float64 9.761e+05 9.761e+05 9.761e+05 ... 9.261e+05 9.261e+05
#   * x        (x) float64 2.928e+06 2.928e+06 2.928e+06 ... 2.978e+06 2.978e+06

# %%
#ts_1[0,:,:].plot()

# %%
# interpolate_na throws an error due to chunking for parallelization. 
# Could be avoid if chunksize didn't split time dimension
ts_2 = sr_0.ndvi.resample(time='10D',
                   loffset=begin_time - 
                   datetime.utcfromtimestamp(sr_0['time'][0].values.astype(datetime)*1e-9)).max('time', 
                                                                                                keep_attrs=True,
                                                                                                skipna=True).chunk({'time': -1}).interpolate_na('time')#

# %%
ts_2
# Out:
# <xarray.DataArray 'ndvi' (time: 9, y: 5002, x: 5002)>
# dask.array<shape=(9, 5002, 5002), dtype=float64, chunksize=(9, 5002, 5002)>
# Coordinates:
#   * time     (time) datetime64[ns] 2019-01-01 2019-01-11 ... 2019-03-22
#   * y        (y) float64 9.761e+05 9.761e+05 9.761e+05 ... 9.261e+05 9.261e+05
#   * x        (x) float64 2.928e+06 2.928e+06 2.928e+06 ... 2.978e+06 2.978e+06

# %%
#ts_2[0,:,:].plot()

# %%
sr_0.ndvi[:,100,100].plot(marker="*")

# %%
ts_1[:,100,100].plot(marker="*")

# %%
ts_2[:,100,100].plot(marker="*")

# %%
#df = ts.to_dataframe()
